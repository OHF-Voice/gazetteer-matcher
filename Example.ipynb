# %%
from pathlib import Path

from gazetteer_matcher import GazetteerMatcher
from gazetteer_matcher.debug import render_interpretation

matcher = GazetteerMatcher(home_path=Path.cwd() / "tests" / "home.yaml")

# %%
result = matcher.interpret("turn on the hallway light and set its brightness to 40%")
print(render_interpretation(result))
# Out:
# TOKENS
# idx  text                 chars
# ---  -------------------  ---------
#   0  turn                 0:4
#   1  on                   5:7
#   2  the                  8:11
#   3  hallway              12:19
#   4  light                20:25
#   5  and                  26:29
#   6  set                  30:33
#   7  its                  34:37
#   8  brightness           38:48
#   9  to                   49:51
#  10  40                   52:54
#  11  %                    54:55
#
# SPANS
# range    tag                 source            sim    value / text
# -------  ------------------  ----------------  -----  ------------------------------
#  0:2    action              exact              1.00  'turn_on' <- 'turn on'
#  1:2    relation            exact              1.00  'on' <- 'on'
#  1:2    slot_marker         exact              1.00  'floor_relation' <- 'on'
#  1:2    state               exact              1.00  'on' <- 'on'
# ...
